# %%
#!jt -t chesterish -T -N -f roboto -fs 10
from strategies.vnDataFeeder import SpreadDataFeeder

# %%
fut_contract_hist_path =  r'C:\Users\lingy\git-repo\xtt\quantresearch\dataset\future_contract_hist'
sprd_datafeeder = SpreadDataFeeder(fut_c_hist_path = '', refetch = True)
# Out:
# future contract path missing, using default: .//dataset//future_contract_hist

# %%
sprd_datafeeder.set_spreads()

# %%
sprd_datafeeder.fetch_legs_data()
# Out:
# ticker cu2203 loaded to db:True; Count 1023; db closed:True
# ticker cu2204 loaded to db:True; Count 1022; db closed:True
# ticker cu2205 loaded to db:True; Count 1022; db closed:True
# ticker IC2203 loaded to db:True; Count 1022; db closed:True
# ticker IC2206 loaded to db:True; Count 1022; db closed:True

# %%
sprd_datafeeder.check_spreads()
# Out:
# ticker cu2203 loaded:1166 counts for 4 days.
# ticker cu2204 loaded:1167 counts for 4 days.
# ticker cu2205 loaded:1166 counts for 4 days.
# ticker IC2203 loaded:1183 counts for 6 days.
# ticker IC2206 loaded:1183 counts for 6 days.
# spread cu34 loaded:1161 counts for 4 days.
# spread cu45 loaded:1097 counts for 4 days.
# spread IC36 loaded:1183 counts for 6 days.
