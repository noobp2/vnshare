# %%
#!jt -t chesterish -T -N -f roboto -fs 10
from strategies.vnDataFeeder import SpreadDataFeeder

# %%
fut_contract_hist_path =  r'E:\dataset\future_contract_hist'
sprd_datafeeder = SpreadDataFeeder(fut_c_hist_path = fut_contract_hist_path, refetch = False)

# %%
sprd_datafeeder.set_spreads()
# Out:
# pricetick:0
# pricetick:0
# pricetick:0
# pricetick:0
# pricetick:0
# pricetick:0
# pricetick:0

# %%
sprd_datafeeder.fetch_legs_data()
# Out:
# ticker cu2203 loaded to db:True; Count 15610; db closed:True
# ticker cu2204 loaded to db:True; Count 15288; db closed:True
# ticker cu2205 loaded to db:True; Count 14752; db closed:True
# ticker cu2206 loaded to db:True; Count 11459; db closed:True
# ticker cu2208 loaded to db:True; Count 2853; db closed:True
# ticker ag2203 loaded to db:True; Count 14238; db closed:True
# ticker ag2204 loaded to db:True; Count 16060; db closed:True
# ticker ag2206 loaded to db:True; Count 18441; db closed:True
# ticker ag2208 loaded to db:True; Count 9357; db closed:True

# %%
sprd_datafeeder.check_spreads()
# Out:
# ticker cu2203 loaded:2748 counts for 7 days.
# ticker cu2204 loaded:2784 counts for 7 days.
# ticker cu2205 loaded:2709 counts for 7 days.
# ticker cu2206 loaded:2319 counts for 7 days.
# ticker cu2208 loaded:315 counts for 7 days.
# ticker ag2203 loaded:1563 counts for 8 days.
# ticker ag2204 loaded:2572 counts for 8 days.
# ticker ag2206 loaded:3340 counts for 8 days.
# ticker ag2208 loaded:3021 counts for 8 days.
# spread cu34 loaded:2746 counts for 7 days.
# spread cu35 loaded:2677 counts for 7 days.
# spread cu36 loaded:2305 counts for 7 days.
# spread cu38 loaded:314 counts for 7 days.
# spread ag34 loaded:1428 counts for 8 days.
# spread ag36 loaded:1563 counts for 8 days.
# spread ag38 loaded:1498 counts for 8 days.
